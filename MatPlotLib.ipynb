# %%
pip install matplotlib
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/86/e4/1ef1cb7f2c52345a7e3c8efd3de7ec943818c0011c839b4880c0ba0bb7b1/matplotlib-3.1.3-cp38-cp38-win32.whl
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 19.2.3, however version 20.0.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x=np.array([1,2,3,4,5])

# %%
xsq=x**2

# %% [markdown]
# # lineplot

# %%
plt.plot(x,x, marker="*")
plt.show()
plt.plot(x,xsq, marker="o")
plt.xlabel("numbers")
plt.ylabel("compare")
plt.title("first graph")
plt.show()

# %%
##scatter graph

# %%
X=np.random.randn(100,2)

# %%
X.shape
# Out:
# (100, 2)

# %%
s=X[ : , 0 ]
d=X[ : , 1 ]

# %%
s
# Out:
# array([-0.22263976,  0.58207905, -1.08391235,  0.1454711 ,  0.47631797,
#         0.54598095, -0.01515723, -0.26569082,  0.66841501,  0.14813681,
#         0.01244427, -0.60589168,  1.19776596,  0.0853277 ,  0.30030357,
#        -0.8278682 , -1.68931087, -0.99272868, -0.77056589,  0.55435692,
#        -0.94199498, -1.84951658,  0.16029045, -0.31765133, -0.15151309,
#         0.36749368, -1.68544165, -0.49155235, -0.00922346, -0.90296388,
#         1.23191271,  0.90749175,  0.25512934, -0.53528502,  2.20111409,
#        -0.06195344,  2.48445003, -1.47137406,  0.76251587, -0.85721419,
#         0.28500319,  0.50374094,  0.72121832, -1.31035491,  0.69132056,
#         1.06811825, -1.29905812, -0.59148079, -1.80627757, -0.18285034,
#        -0.97786882,  0.83749954,  0.13496515, -0.71382731,  1.27109399,
#        -1.61541535,  1.78904364,  1.27162256,  1.64368505, -1.60408865,
#         0.32227372,  0.14349839, -0.39510003,  0.90708442,  1.8378858 ,
# ...

# %%
plt.scatter(s,d)

# %%
## bar graph

# %%
x
# Out:
# array([1, 2, 3, 4, 5])

# %%
scar1=np.array([10,13,8,5,20])
scar2=np.array([13,6,9,12,10])

# %%
plt.bar(x,height=scar1, width=0.3,color="orange")
plt.bar(x+0.3,height=scar2, width=0.3)
plt.show()

# %%
pip install pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 19.2.3, however version 20.0.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %% [markdown]
# # images

# %%
img=plt.imread("./cat.jpg")

# %%
img.shape
# Out:
# (3000, 4000, 3)

# %%
plt.imshow(img)

# %%
new=img[1500:2000, 1500:3000,]

# %%
plt.imshow(new)

# %%
fakeimg=img.copy()

# %%
fakeimg[ : , : , 0]=0
plt.imshow(fakeimg)
